# %% [markdown]
# # Module objectives
# - Navigation and instructions

# %% [markdown]
# ## How to open module on the Jupyter Server
# Select File -> Open from URL ...
#
# Module 1:
# https://raw.githubusercontent.com/erikbijl/genai-workshop-amsterdam/refs/heads/main/talent/Module_01_GraphSummit_Amsterdam_2025.ipynb
#
# Module 2:
# https://raw.githubusercontent.com/erikbijl/genai-workshop-amsterdam/refs/heads/main/talent/Module_02_GraphSummit_Amsterdam_2025.ipynb
#
# Module 3:
# https://raw.githubusercontent.com/erikbijl/genai-workshop-amsterdam/refs/heads/main/talent/Module_03_GraphSummit_Amsterdam_2025.ipynb

# %% [markdown]
# ## Neo4j Browser
# https://browser.neo4j.io/preview/
